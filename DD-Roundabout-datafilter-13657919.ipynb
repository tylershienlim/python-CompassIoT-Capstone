# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
"""
Graph mining links and examples:

https://github.com/RISHIKESHAVAN/link-prediction/blob/main/code/citation-network.ipynb

https://github.com/topics/graph-mining?o=asc&s=stars

https://github.com/topics/graph-mining
"""
# Out:
# '\nGraph mining links and examples:\n\nhttps://github.com/RISHIKESHAVAN/link-prediction/blob/main/code/citation-network.ipynb\n\nhttps://github.com/topics/graph-mining?o=asc&s=stars\n\nhttps://github.com/topics/graph-mining\n'

# %%
#data sets to load
crash_data = gpd.read_file('data/act_crash_data.geojson')
merged_data = gpd.read_file('data/merged.geojson')
roundabouts_data = gpd.read_file('data/roundabout.geojson')

# %% [markdown]
# Data Loading and Filtering for accident/DDB points at roundabouts only

# %%
crash_data.head()
# Out:
#    CRASH_ID  CRASH_DATE CRASH_TIME SUBURB_LOCATION   LONGITUDE   LATITUDE  \
# 0   1025691  13/01/2012   09:18:00          KAMBAH  149.055056 -35.392007
# 1   1039779  05/04/2012   17:30:00         PHILLIP  149.084447 -35.348921
# 2   1048742  28/10/2012   11:48:00            HALL  149.061431 -35.172863
# 3   1041937  07/08/2012   17:00:00       BELCONNEN  149.094072 -35.201315
# 4   1048339  01/11/2012   14:45:00        HARRISON  149.156400 -35.197308
#
#   INTERSECTION MIDBLOCK CRASH_DIRECTION        CRASH_SEVERITY  \
# 0           NO      YES      East bound                Injury
# 1          YES       NO      West bound                Injury
# 2           NO      YES     South bound                Injury
# 3          YES       NO     North bound  Property Damage Only
# 4          YES       NO     South bound                Injury
#
#   LIGHTING_CONDITION    ROAD_CONDITION WEATHER_CONDITION  \
# 0           Daylight  Good dry surface              Fine
# 1           Daylight  Good dry surface              Fine
# 2           Daylight  Good dry surface              Fine
# 3           Daylight  Good dry surface              Fine
# 4           Daylight  Good dry surface              Fine
#
#                                     Location                     geometry
# 0  (-35.392006654135606, 149.05505612950844)  POINT (149.05506 -35.39201)
# 1    (-35.34892137433122, 149.0844465057644)  POINT (149.08445 -35.34892)
# 2   (-35.172862707340954, 149.0614313347401)  POINT (149.06143 -35.17286)
# 3  (-35.201315499751615, 149.09407196860244)  POINT (149.09407 -35.20132)
# 4   (-35.19730828458103, 149.15639997910796)  POINT (149.15640 -35.19731)

# %%
crash_data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
crash_data = crash_data.to_crs(3857)
crash_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
merged_data.head()
# Out:
#                   timestamp   xacc   yacc  speed  maxspeed  lanecount  \
# 0 2022-01-03 01:49:36+00:00 -0.622 -0.255     29        62          1
# 1 2020-07-01 02:17:01+00:00  1.394 -0.600     64        83          4
# 2 2023-01-25 06:32:38+00:00 -1.114  0.017     27        48          2
# 3 2021-06-23 07:33:19+00:00 -0.976  0.396     17        22          1
# 4 2021-03-03 21:55:16+00:00 -0.896  0.003     67        95          2
#
#   classification                     geometry
# 0        Braking  POINT (149.00200 -35.76227)
# 1       Steering  POINT (149.05411 -35.32600)
# 2        Braking  POINT (149.06319 -35.32026)
# 3        Braking  POINT (149.06277 -35.32006)
# 4        Braking  POINT (149.06238 -35.31332)

# %%
merged_data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
merged_data = merged_data.to_crs(3857)
merged_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
roundabouts_data = roundabouts_data[['geometry']]
roundabouts_data
# Out:
#                                               geometry
# 0    POLYGON ((149.02752 -35.20240, 149.02752 -35.2...
# 1    POLYGON ((149.03340 -35.20588, 149.03338 -35.2...
# 2    POLYGON ((149.02890 -35.19941, 149.02891 -35.1...
# 3    POLYGON ((149.02712 -35.20537, 149.02708 -35.2...
# 4    LINESTRING (149.16504 -35.22496, 149.16497 -35...
# ..                                                 ...
# 899  LINESTRING (149.14601 -35.24354, 149.14602 -35...
# 900  LINESTRING (149.14610 -35.24351, 149.14610 -35...
# 901  LINESTRING (149.08657 -35.33668, 149.08649 -35...
# 902  LINESTRING (149.15659 -35.20972, 149.15668 -35...
# 903  LINESTRING (149.09820 -35.31325, 149.09820 -35...
#
# [904 rows x 1 columns]

# %%
roundabouts_data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
roundabouts_data = roundabouts_data.to_crs(3857)
roundabouts_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#spatial join for DDB to roundabouts
ddb_roundabout = gpd.sjoin_nearest(merged_data, roundabouts_data, max_distance=100, distance_col='distances', how='left')

# %%
ddb_roundabout = ddb_roundabout[~ddb_roundabout['distances'].isna()]

# %%
ddb_roundabout.head()
# Out:
#                    timestamp   xacc   yacc  speed  maxspeed  lanecount  \
# 7  2020-12-17 01:46:30+00:00 -0.889  0.002      7        32          1
# 9  2020-07-05 23:53:50+00:00 -0.864  0.000      3        48          1
# 9  2020-07-05 23:53:50+00:00 -0.864  0.000      3        48          1
# 20 2020-04-25 19:27:59+00:00 -0.346  0.714     27        45          1
# 20 2020-04-25 19:27:59+00:00 -0.346  0.714     27        45          1
#
#    classification                           geometry  index_right  distances
# 7         Braking  POINT (16595825.835 -4208110.694)        402.0  78.508285
# 9         Braking  POINT (16597539.710 -4206559.210)         70.0  27.548220
# 9         Braking  POINT (16597539.710 -4206559.210)        903.0  27.548220
# 20       Steering  POINT (16597536.370 -4206536.837)         70.0   4.927812
# 20       Steering  POINT (16597536.370 -4206536.837)        903.0   4.927812

# %%
#spatial join for crash data to roundabouts
crash_roundabout = gpd.sjoin_nearest(crash_data, roundabouts_data, max_distance=100, distance_col='distances', how='left')

# %%
crash_roundabout = crash_roundabout[~crash_roundabout['distances'].isna()]

# %%
crash_roundabout.head()
# Out:
#     CRASH_ID  CRASH_DATE CRASH_TIME SUBURB_LOCATION   LONGITUDE   LATITUDE  \
# 8    1082208  14/03/2014   14:45:00       WANNIASSA  149.105038 -35.394988
# 9    1071548  25/09/2013   09:15:00          PARKES  149.140739 -35.290364
# 12   1097139  21/10/2014   12:50:00          WESTON  149.052234 -35.342376
# 21   1101688  18/12/2014   15:00:00          CURTIN  149.085469 -35.336601
# 30   1116903  04/08/2015   07:10:00          CURTIN  149.085534 -35.336096
#
#    INTERSECTION MIDBLOCK     CRASH_DIRECTION        CRASH_SEVERITY  \
# 8           YES       NO         North bound  Property Damage Only
# 9           YES       NO         South bound                Injury
# 12          YES       NO  South / West bound                Injury
# 21          YES       NO         North bound  Property Damage Only
# 30          YES       NO  North / East bound                Injury
#
#    LIGHTING_CONDITION    ROAD_CONDITION WEATHER_CONDITION  \
# 8            Daylight  Good dry surface              Fine
# 9            Daylight  Good dry surface              Fine
# 12           Daylight  Good dry surface              Fine
# 21           Daylight  Good dry surface              Fine
# 30           Daylight  Good dry surface              Fine
#
#                                      Location  \
# 8    (-35.394987516718835, 149.1050382804053)
# 9     (-35.2903638694626, 149.14073893625283)
# 12  (-35.342376051736125, 149.05223439721874)
# 21   (-35.33660063969841, 149.08546898336647)
# 30   (-35.336095898518856, 149.0855345007159)
#
#                              geometry  index_right  distances
# 8   POINT (16598296.938 -4217688.770)        124.0  54.232167
# 9   POINT (16602271.111 -4203410.781)        598.0  18.107638
# 12  POINT (16592418.835 -4210506.572)        109.0  52.375484
# 21  POINT (16596118.494 -4209718.433)        302.0  37.911366
# 30  POINT (16596125.785 -4209649.556)        302.0   1.119271

# %%
crash_roundabout = crash_roundabout.drop(columns='CRASH_ID')

# %%
#export data ddb
ddb_roundabout.to_file('data/ddb_roundabout.geojson', driver='GeoJSON')

# %%
#export data crash
crash_roundabout.to_file('data/crash_roundabout.geojson', driver='GeoJSON')
